# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from PerturbSeq_CMV.paths import DATA_DIR

# %%
folder_CRISPRn_pooled = DATA_DIR / "rawdata" / "CRISPRn_screen_virus_processed"
folder_CRISPRn_processed = DATA_DIR / "processed"

# %% [markdown]
# Read the phenotype data

# %%
crisprn_df_ratios = pd.read_excel(folder_CRISPRn_pooled / "CRISPR_viral_factors.xlsx", header=0, sheet_name=1)

# %%
crisprn_df_ratios
# Out:
#              name           type   start     end strand        boundaries  \
# 0             TRL  repeat_region       1    1324      +         [1, 1324]
# 1    'a' sequence  repeat_region       1     578      +          [1, 578]
# 2             RL1            CDS    1367    2299      +      [1367, 2299]
# 3          RNA2.7          ncRNA    2489    4969      -      [2489, 4969]
# 4            RL5A            CDS    5389    5676      -      [5389, 5676]
# ..            ...            ...     ...     ...    ...               ...
# 182          US34            CDS  230716  231207      +  [230716, 231207]
# 183         US34A            CDS  231201  231395      +  [231201, 231395]
# 184          TRS1            CDS  232393  234759      -  [232393, 234759]
# 185           TRS  repeat_region  233109  235646      +  [233109, 235646]
# 186  'a' sequence  repeat_region  235068  235646      +  [235068, 235646]
#
#      has_introns Dunn_phenotype  CRISPRn_phenotype  \
# ...

# %%
crisprn_df_ratios.to_csv(folder_CRISPRn_processed / "CRISPRn_virus_factors.csv")
