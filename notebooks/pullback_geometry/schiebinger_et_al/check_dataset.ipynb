# %%
import scanpy as sc

# %%
adata = sc.read_h5ad("/nfs/students/pala/scCFM/data/schiebinger_et_al/processed/schiebinger_et_al.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 165892 × 1479
#     obs: 'day', 'MEF.identity', 'Pluripotency', 'Cell.cycle', 'ER.stress', 'Epithelial.identity', 'ECM.rearrangement', 'Apoptosis', 'SASP', 'Neural.identity', 'Placental.identity', 'X.reactivation', 'XEN', 'Trophoblast', 'Trophoblast progenitors', 'Spiral Artery Trophpblast Giant Cells', 'Spongiotrophoblasts', 'Oligodendrocyte precursor cells (OPC)', 'Astrocytes', 'Cortical Neurons', 'RadialGlia-Id3', 'RadialGlia-Gdf10', 'RadialGlia-Neurog2', 'Long-term MEFs', 'Embryonic mesenchyme', 'Cxcl12 co-expressed', 'Ifitm1 co-expressed', 'Matn4 co-expressed', '2-cell', '4-cell', '8-cell', '16-cell', '32-cell', 'cell_growth_rate', 'serum', '2i', 'major_cell_sets', 'cell_sets', 'batch', 'experimental_time'
#     var: 'highly_variable', 'TF'
#     uns: 'batch_colors', 'cell_sets_colors', 'day_colors', 'major_cell_sets_colors', 'neighbors', 'pca', 'umap'
#     obsm: 'X_force_directed', 'X_pca', 'X_umap'
#     varm: 'PCs'
# ...

# %%
adata.layers["X_norm"].A.shape
# Out:
# (165892, 1479)

# %%
for i in adata.obs.columns:
    print(i)
# Out:
# day
# MEF.identity
# Pluripotency
# Cell.cycle
# ER.stress
# Epithelial.identity
# ECM.rearrangement
# Apoptosis
# SASP
# Neural.identity
# Placental.identity
# X.reactivation
# XEN
# Trophoblast
# Trophoblast progenitors
# Spiral Artery Trophpblast Giant Cells
# Spongiotrophoblasts
# Oligodendrocyte precursor cells (OPC)
# Astrocytes
# Cortical Neurons
# RadialGlia-Id3
# RadialGlia-Gdf10
# RadialGlia-Neurog2
# Long-term MEFs
# Embryonic mesenchyme
# Cxcl12 co-expressed
# Ifitm1 co-expressed
# Matn4 co-expressed
# 2-cell
# 4-cell
# 8-cell
# 16-cell
# 32-cell
# cell_growth_rate
# serum
# 2i
# major_cell_sets
# cell_sets
# batch
# experimental_time

# %%
sc.pl.umap(adata, color=["cell_sets", "experimental_time", "major_cell_sets", "batch"])
# Out:
# /nfs/staff-ssd/pala/envs/scCFM/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /nfs/staff-ssd/pala/envs/scCFM/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /nfs/staff-ssd/pala/envs/scCFM/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.pca(adata, color=["cell_sets", "experimental_time"])
# Out:
# /nfs/staff-ssd/pala/envs/scCFM/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
