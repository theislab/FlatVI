# %%
import os 
import pytorch_lightning as pl
import seml
import numpy as np
import torch

import scanpy as sc
import scvelo as scv
import cellrank as cr
import pandas as pd

from scCFM.datamodules.sc_datamodule import scDataModule
from scCFM.models.base.vae import AE
from scvi.distributions import NegativeBinomial

import matplotlib.pyplot as plt

import yaml

import sys 
sys.path.insert(0, "../../../" )
from paths import EXPERIMENT_FOLDER

# %%
# import wandb
# run = wandb.init()
# artifact = run.use_artifact('allepalma/scCFM_ae_sweep_lib/model-ltm3cziv:v0', type='model')
# artifact_dir = artifact.download()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: allepalma. Use `wandb login --relogin` to force relogin
# wandb version 0.15.8 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.5
# Run data is saved locally in <code>/nfs/homedirs/pala/scCFM/notebooks/train_autoencoder/eb/wandb/run-20230816_182642-fjixtzn0</code>
# Syncing run <strong><a href='https://wandb.ai/allepalma/scCFM-notebooks_train_autoencoder_eb/runs/fjixtzn0' target="_blank">pretty-grass-6</a></strong> to <a href='https://wandb.ai/allepalma/scCFM-notebooks_train_autoencoder_eb' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/allepalma/scCFM-notebooks_train_autoencoder_eb' target="_blank">https://wandb.ai/allepalma/scCFM-notebooks_train_autoencoder_eb</a>
#  View run at <a href='https://wandb.ai/allepalma/scCFM-notebooks_train_autoencoder_eb/runs/fjixtzn0' target="_blank">https://wandb.ai/allepalma/scCFM-notebooks_train_autoencoder_eb/runs/fjixtzn0</a>
# wandb:   1 of 1 files downloaded.

# %%
datamodule={'path': '/nfs/homedirs/pala/scCFM/project_dir/data/eb/processed/eb_phate.h5ad', 
            'x_layer': 'X_norm', 
            'cond_key': 'experimental_time', 
            'use_pca': False, 
            'n_dimensions': None, 
            'train_val_test_split': [0.8, 0.2],
            'batch_size': 256, 'num_workers': 2}

model_config = {'likelihood': 'nb', 
                  'dropout': False, 
                  'dropout_p': False, 
                  'hidden_dims': [512, 256, 64], 
                  'batch_norm': False, 
                  'model_log_library_size': True, 
               }

# %%
# Initialize datamodule
datamodule = scDataModule(**datamodule)



# Initialize the model 
model = AE(in_dim = datamodule.in_dim,
            **model_config)

# %%
model.load_state_dict(torch.load("/nfs/homedirs/pala/scCFM/notebooks/train_autoencoder/eb/models_ae/model_lib.ckpt")["state_dict"])
# Out:
# <All keys matched successfully>

# %% [markdown]
# **Latent space structure**

# %%
cells = []
annot = []


with torch.no_grad():
    for batch in datamodule.train_dataloader():
        annot.append(batch["cond"])
        mu = model.encode(batch["X"])["z"]
        cells.append(mu)

# %%
cells= torch.cat(cells, dim=0)
annot = pd.DataFrame(torch.cat(annot).numpy())
annot.columns = ["experimental_time"]

# %%
adata = sc.AnnData(X=cells.cpu().numpy(), 
                  obs=annot)
# Out:
# /nfs/staff-ssd/pala/envs/scCFM/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
sc.tl.pca(adata)
sc.pp.neighbors(adata)
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color="experimental_time")

# %% [markdown]
# **Generative model from amoritzed**

# %%
real_data = [] 
generated_amortized_data = []
annot = []

with torch.no_grad():
    for batch in datamodule.train_dataloader():
        real_data.append(batch["X"].numpy())
        annot.append(batch["cond"])
        # Amortized
        decoder_output = model(batch, library_size=None)
        nb = NegativeBinomial(mu=decoder_output["mu"], theta=torch.exp(model.theta))
        generated_amortized_data.append(nb.sample())

# %%
real_data = np.concatenate(real_data)
generated_amortized_data = np.concatenate(generated_amortized_data)
annot = pd.DataFrame(torch.cat(annot).numpy())
annot.columns = ["experimental_time"]

# %%
amortized_and_real = np.concatenate([real_data, generated_amortized_data], axis=0)
dataset_type = ["real" for _ in range(len(real_data))] + ["generated_amortized" for _ in range(len(generated_amortized_data))] 
dataset_type_df = pd.DataFrame(dataset_type)
dataset_type_df.columns = ["dataset_type"]
annot = pd.concat([annot, annot], axis=0).reset_index(drop=True)
annot.columns = ["experimental_time"]

# %%
adata_real_amortized = sc.AnnData(X=amortized_and_real, 
                                      obs=pd.concat([dataset_type_df, annot], axis=1))
# Out:
# /nfs/staff-ssd/pala/envs/scCFM/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
sc.tl.pca(adata_real_amortized)
sc.pp.neighbors(adata_real_amortized)
sc.tl.umap(adata_real_amortized)

# %%
sc.pl.umap(adata_real_amortized, color=["dataset_type", "experimental_time"])
# Out:
# /nfs/staff-ssd/pala/envs/scCFM/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# **Check learnt vs real library size**

# %%
real_lib = [] 
decoded_lib = []

with torch.no_grad():
    for batch in datamodule.train_dataloader():
        z = model.encode(batch["X"])["z"]
        # Amortized
        l_hat = torch.exp(model.decoder_lib(model.decoder_layers(z))).cpu()
        l = batch["X"].sum(1).cpu()
        real_lib.append(l)
        decoded_lib.append(l_hat)

# %%
real_lib = torch.cat(real_lib)
decoded_lib = torch.cat(decoded_lib)

# %%
real_lib
# Out:
# tensor([638.4495, 665.5779, 481.6707,  ..., 699.2377, 886.5936, 697.3992])

# %%
decoded_lib
# Out:
# tensor([[717.9598],
#         [674.9006],
#         [539.1248],
#         ...,
#         [783.0597],
#         [852.0916],
#         [754.2471]])

# %%
plt.scatter(real_lib, decoded_lib)
